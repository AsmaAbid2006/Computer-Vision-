# %%
import cv2
import matplotlib.pyplot as plt
imagePath = 'images/imageb.jpg'

# %%
img = cv2.imread(imagePath)

# %%
img.shape
# Out:
# (298, 337, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
# Out:
# (298, 337)

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40))

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 4)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)




plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 336.5, 297.5, -0.5)

# %%
import cv2
img = cv2.imread("Week2/Task7/images/Imagea.jpg")
# Out:
# [ WARN:0@0.052] global loadsave.cpp:241 findDecoder imread_('Week2/Task7/images/Imagea.jpg'): can't open/read file: check file path/integrity
